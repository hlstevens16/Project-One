# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %%
state_data_path = "Data/homelessness-07to16.csv"

state_data_df = pd.read_csv(state_data_path)
state_data_df
# Out:
#            Year State CoC Number               CoC Name  \
# 0      1/1/2007    AK     AK-500          Anchorage CoC
# 1      1/1/2007    AK     AK-500          Anchorage CoC
# 2      1/1/2007    AK     AK-500          Anchorage CoC
# 3      1/1/2007    AK     AK-500          Anchorage CoC
# 4      1/1/2007    AK     AK-500          Anchorage CoC
# ...         ...   ...        ...                    ...
# 86524  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86525  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86526  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86527  1/1/2016    WY     WY-500  Wyoming Statewide CoC
# 86528  1/1/2016    WY     WY-500  Wyoming Statewide CoC
#
#                                                 Measures Count
# 0                       Chronically Homeless Individuals   224
# 1                                   Homeless Individuals   696
# 2                            Homeless People in Families   278
# 3             Sheltered Chronically Homeless Individuals   187
# 4                                     Sheltered Homeless   842
# ...                                                  ...   ...
# 86524  Unsheltered Homeless Unaccompanied Youth (Unde...     7
# 86525                      Unsheltered Homeless Veterans    31
# 86526             Unsheltered Parenting Youth (Under 25)     3
# 86527              Unsheltered Parenting Youth Age 18-24     3
# 86528               Unsheltered Parenting Youth Under 18     0
#
# [86529 rows x 6 columns]

# %%
measures = state_data_df["Measures"].unique()
measures
# Out:
# array(['Chronically Homeless Individuals', 'Homeless Individuals',
#        'Homeless People in Families',
#        'Sheltered Chronically Homeless Individuals', 'Sheltered Homeless',
#        'Sheltered Homeless Individuals',
#        'Sheltered Homeless People in Families', 'Total Homeless',
#        'Unsheltered Chronically Homeless Individuals',
#        'Unsheltered Homeless', 'Unsheltered Homeless Individuals',
#        'Unsheltered Homeless People in Families', 'Chronically Homeless',
#        'Chronically Homeless People in Families', 'Homeless Veterans',
#        'Sheltered Chronically Homeless',
#        'Sheltered Chronically Homeless People in Families',
#        'Sheltered Homeless Veterans', 'Unsheltered Chronically Homeless',
#        'Unsheltered Chronically Homeless People in Families',
#        'Unsheltered Homeless Veterans', 'Children of Parenting Youth',
#        'Homeless Unaccompanied Children (Under 18)',
#        'Homeless Unaccompanied Young Adults (Age 18-24)',
#        'Homeless Unaccompanied Youth (Under 25)',
#        'Parenting Youth (Under 25)', 'Parenting Youth Age 18-24',
#        'Parenting Youth Under 18',
#        'Sheltered Children of Parenting Youth',
#        'Sheltered Homeless Unaccompanied Children (Under 18)',
#        'Sheltered Homeless Unaccompanied Young Adults (Age 18-24)',
#        'Sheltered Homeless Unaccompanied Youth (Under 25)',
#        'Sheltered Parenting Youth (Under 25)',
#        'Sheltered Parenting Youth Age 18-24',
#        'Sheltered Parenting Youth Under 18',
#        'Unsheltered Children of Parenting Youth',
#        'Unsheltered Homeless Unaccompanied Children (Under 18)',
#        'Unsheltered Homeless Unaccompanied Young Adults (Age 18-24)',
#        'Unsheltered Homeless Unaccompanied Youth (Under 25)',
#        'Unsheltered Parenting Youth (Under 25)',
#        'Unsheltered Parenting Youth Age 18-24',
#        'Unsheltered Parenting Youth Under 18'], dtype=object)

# %%
homeless_children= state_data_df.loc[state_data_df["Measures"] == "Unsheltered Homeless Unaccompanied Children (Under 18)"] 
homeless_children
# Out:
#            Year State CoC Number  \
# 52754  1/1/2015    AK     AK-500
# 52796  1/1/2015    AK     AK-501
# 52838  1/1/2015    AL     AL-500
# 52880  1/1/2015    AL     AL-501
# 52922  1/1/2015    AL     AL-502
# ...         ...   ...        ...
# 86354  1/1/2016    WV     WV-500
# 86396  1/1/2016    WV     WV-501
# 86438  1/1/2016    WV     WV-503
# 86480  1/1/2016    WV     WV-508
# 86522  1/1/2016    WY     WY-500
#
#                                                 CoC Name  \
# 52754                                      Anchorage CoC
# 52796                        Alaska Balance of State CoC
# 52838  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 52880            Mobile City & County/Baldwin County CoC
# 52922                     Florence/Northwest Alabama CoC
# ...                                                  ...
# 86354                          Wheeling/Weirton Area CoC
# 86396              Huntington/Cabell, Wayne Counties CoC
# 86438  Charleston/Kanawha, Putnam, Boone, Clay Counti...
# 86480                 West Virginia Balance of State CoC
# 86522                              Wyoming Statewide CoC
#
#                                                 Measures Count
# 52754  Unsheltered Homeless Unaccompanied Children (U...     3
# 52796  Unsheltered Homeless Unaccompanied Children (U...     3
# 52838  Unsheltered Homeless Unaccompanied Children (U...     0
# 52880  Unsheltered Homeless Unaccompanied Children (U...     0
# 52922  Unsheltered Homeless Unaccompanied Children (U...     0
# ...                                                  ...   ...
# 86354  Unsheltered Homeless Unaccompanied Children (U...     0
# 86396  Unsheltered Homeless Unaccompanied Children (U...     0
# 86438  Unsheltered Homeless Unaccompanied Children (U...     0
# 86480  Unsheltered Homeless Unaccompanied Children (U...     1
# 86522  Unsheltered Homeless Unaccompanied Children (U...     2
#
# [805 rows x 6 columns]

# %%
cleaned_homeless_children = homeless_children.dropna()
cleaned_homeless_children
# Out:
#            Year State CoC Number  \
# 52754  1/1/2015    AK     AK-500
# 52796  1/1/2015    AK     AK-501
# 52838  1/1/2015    AL     AL-500
# 52880  1/1/2015    AL     AL-501
# 52922  1/1/2015    AL     AL-502
# ...         ...   ...        ...
# 86354  1/1/2016    WV     WV-500
# 86396  1/1/2016    WV     WV-501
# 86438  1/1/2016    WV     WV-503
# 86480  1/1/2016    WV     WV-508
# 86522  1/1/2016    WY     WY-500
#
#                                                 CoC Name  \
# 52754                                      Anchorage CoC
# 52796                        Alaska Balance of State CoC
# 52838  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 52880            Mobile City & County/Baldwin County CoC
# 52922                     Florence/Northwest Alabama CoC
# ...                                                  ...
# 86354                          Wheeling/Weirton Area CoC
# 86396              Huntington/Cabell, Wayne Counties CoC
# 86438  Charleston/Kanawha, Putnam, Boone, Clay Counti...
# 86480                 West Virginia Balance of State CoC
# 86522                              Wyoming Statewide CoC
#
#                                                 Measures Count
# 52754  Unsheltered Homeless Unaccompanied Children (U...     3
# 52796  Unsheltered Homeless Unaccompanied Children (U...     3
# 52838  Unsheltered Homeless Unaccompanied Children (U...     0
# 52880  Unsheltered Homeless Unaccompanied Children (U...     0
# 52922  Unsheltered Homeless Unaccompanied Children (U...     0
# ...                                                  ...   ...
# 86354  Unsheltered Homeless Unaccompanied Children (U...     0
# 86396  Unsheltered Homeless Unaccompanied Children (U...     0
# 86438  Unsheltered Homeless Unaccompanied Children (U...     0
# 86480  Unsheltered Homeless Unaccompanied Children (U...     1
# 86522  Unsheltered Homeless Unaccompanied Children (U...     2
#
# [805 rows x 6 columns]

# %%
total_homeless= state_data_df.loc[state_data_df["Measures"] == "Total Homeless"] 
total_homeless
# Out:
#            Year State CoC Number  \
# 7      1/1/2007    AK     AK-500
# 19     1/1/2007    AK     AK-501
# 31     1/1/2007    AL     AL-500
# 43     1/1/2007    AL     AL-501
# 55     1/1/2007    AL     AL-502
# ...         ...   ...        ...
# 86346  1/1/2016    WV     WV-500
# 86388  1/1/2016    WV     WV-501
# 86430  1/1/2016    WV     WV-503
# 86472  1/1/2016    WV     WV-508
# 86514  1/1/2016    WY     WY-500
#
#                                                 CoC Name        Measures  \
# 7                                          Anchorage CoC  Total Homeless
# 19                           Alaska Balance of State CoC  Total Homeless
# 31     Birmingham/Jefferson, St. Clair, Shelby Counti...  Total Homeless
# 43               Mobile City & County/Baldwin County CoC  Total Homeless
# 55                        Florence/Northwest Alabama CoC  Total Homeless
# ...                                                  ...             ...
# 86346                          Wheeling/Weirton Area CoC  Total Homeless
# 86388              Huntington/Cabell, Wayne Counties CoC  Total Homeless
# 86430  Charleston/Kanawha, Putnam, Boone, Clay Counti...  Total Homeless
# 86472                 West Virginia Balance of State CoC  Total Homeless
# 86514                              Wyoming Statewide CoC  Total Homeless
#
#        Count
# 7        974
# 19       668
# 31     2,104
# 43       649
# 55       265
# ...      ...
# 86346     91
# 86388    228
# 86430    320
# 86472    748
# 86514    857
#
# [3999 rows x 6 columns]

# %%
all_states = total_homeless["State"].unique()
all_states
# Out:
# array(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
#        'GU', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD',
#        'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ',
#        'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'SC', 'SD',
#        'TN', 'TX', 'UT', 'VA', 'VI', 'VT', 'WA', 'WI', 'WV', 'WY'],
#       dtype=object)

# %%
state_list = ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
       'GU', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD',
       'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ',
       'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'SC', 'SD',
       'TN', 'TX', 'UT', 'VA', 'VI', 'VT', 'WA', 'WI', 'WV', 'WY']

for state in state_list:
    state_total_homeless = total_homeless["State"] == state
