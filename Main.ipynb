# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
datatract = pd.read_csv('Data/homeless-tracts-2016.csv')
datatract#.head()
# Out:
#       censusTract  Year         City              CommunityName  \
# 0          101110  2016  Los Angeles            Sunland-Tujunga
# 1          101122  2016  Los Angeles            Sunland-Tujunga
# 2          101210  2016  Los Angeles            Sunland-Tujunga
# 3          101220  2016  Los Angeles            Sunland-Tujunga
# 4          101300  2016  Los Angeles            Sunland-Tujunga
# ...           ...   ...          ...                        ...
# 2150       980025  2016       Carson                     Carson
# 2151       980026  2016  Los Angeles            Sunland-Tujunga
# 2152       980028  2016  Los Angeles  Westchester/Playa Del Rey
# 2153       980030  2016   El Segundo                 El Segundo
# 2154       980031  2016  Los Angeles                 Wilmington
#
#              Detailed_Name  SPA  SD  CD  SSD  AD  ...  totShYouthSingYouth  \
# 0       Sunland-Tujunga NC    2   5   7   25  39  ...                    0
# ...

# %%
grouped_df = datatract.groupby(datatract['SPA'])
grouped_df.head()
# y_axis = grouped_df['totPeople']
# x_axis = np.arange(1,8,1)
# graphspa = plt.scatter(x_axis, y_axis, marker ='o', color='blue')
# plt.show()
# Each point on the cosine chart is marked by a red triangle
# Out:
#       censusTract  Year                            City  \
# 0          101110  2016                     Los Angeles
# 1          101122  2016                     Los Angeles
# 2          101210  2016                     Los Angeles
# 3          101220  2016                     Los Angeles
# 4          101300  2016                     Los Angeles
# 349        143700  2016                     Los Angeles
# 353        181000  2016                     Los Angeles
# 354        181300  2016                     Los Angeles
# 355        181400  2016                     Los Angeles
# 356        181500  2016                     Los Angeles
# 457        194200  2016                     Los Angeles
# 458        194300  2016                     Los Angeles
# 638        216401  2016                     Los Angeles
# 639        216402  2016                     Los Angeles
# 643        217001  2016                     Los Angeles
# 647        218110  2016                     Los Angeles
# ...
